# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# %%
df=pd.read_csv("Downloads/pizza.csv")
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1  01-01-2015
# 1                     2         2  classic_dlx_m         1  01-01-2015
# 2                     3         2  five_cheese_l         1  01-01-2015
# 3                     4         2    ital_supr_l         1  01-01-2015
# 4                     5         2     mexicana_m         1  01-01-2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  31-12-2015
# 48616             48617     21348  four_cheese_l         1  31-12-2015
# 48617             48618     21348   napolitana_s         1  31-12-2015
# 48618             48619     21349     mexicana_l         1  31-12-2015
# 48619             48620     21350      bbq_ckn_s         1  31-12-2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.isnull()
# Out:
#        order_details_id  order_id  pizza_id  quantity  order_date  order_time  \
# 0                 False     False     False     False       False       False
# 1                 False     False     False     False       False       False
# 2                 False     False     False     False       False       False
# 3                 False     False     False     False       False       False
# 4                 False     False     False     False       False       False
# ...                 ...       ...       ...       ...         ...         ...
# 48615             False     False     False     False       False       False
# 48616             False     False     False     False       False       False
# 48617             False     False     False     False       False       False
# 48618             False     False     False     False       False       False
# 48619             False     False     False     False       False       False
#
# ...

# %%
df.describe(include="all")
# Out:
#         order_details_id      order_id    pizza_id      quantity  order_date  \
# count       48620.000000  48620.000000       48620  48620.000000       48620
# unique               NaN           NaN          91           NaN         358
# top                  NaN           NaN  big_meat_s           NaN  26-11-2015
# freq                 NaN           NaN        1811           NaN         261
# mean        24310.500000  10701.479761         NaN      1.019622         NaN
# std         14035.529381   6180.119770         NaN      0.143077         NaN
# min             1.000000      1.000000         NaN      1.000000         NaN
# 25%         12155.750000   5337.000000         NaN      1.000000         NaN
# 50%         24310.500000  10682.500000         NaN      1.000000         NaN
# 75%         36465.250000  16100.000000         NaN      1.000000         NaN
# max         48620.000000  21350.000000         NaN      4.000000         NaN
#
# ...

# %%
df.pizza_name.value_counts()
# Out:
# pizza_name
# The Classic Deluxe Pizza                      2416
# The Barbecue Chicken Pizza                    2372
# The Hawaiian Pizza                            2370
# The Pepperoni Pizza                           2369
# The Thai Chicken Pizza                        2315
# The California Chicken Pizza                  2302
# The Sicilian Pizza                            1887
# The Spicy Italian Pizza                       1887
# The Southwest Chicken Pizza                   1885
# The Four Cheese Pizza                         1850
# The Italian Supreme Pizza                     1849
# The Big Meat Pizza                            1811
# The Vegetables + Vegetables Pizza             1510
# The Mexicana Pizza                            1456
# The Napolitana Pizza                          1451
# The Spinach and Feta Pizza                    1432
# The Prosciutto and Arugula Pizza              1428
# The Pepper Salami Pizza                       1422
# ...

# %%
df.pizza_name.value_counts().count()
# There are 32 names of pizza in this data.
# Out:
# 32

# %%
df.order_time
# Out:
# 0        11:38:36
# 1        11:57:40
# 2        11:57:40
# 3        11:57:40
# 4        11:57:40
#            ...
# 48615    21:23:10
# 48616    21:23:10
# 48617    21:23:10
# 48618    22:09:54
# 48619    23:02:05
# Name: order_time, Length: 48620, dtype: object

# %%
df.dtypes
# Out:
# order_details_id       int64
# order_id               int64
# pizza_id              object
# quantity               int64
# order_date            object
# order_time            object
# unit_price           float64
# total_price          float64
# pizza_size            object
# pizza_category        object
# pizza_ingredients     object
# pizza_name            object
# dtype: object

# %%
df[["order_id"]].value_counts()
# There are many customers who buys more than 1 pizza in a single order.
# Out:
# order_id
# 18845       21
# 10760       21
# 18280       15
# 21158       15
# 17464       15
#             ..
# 10351        1
# 10355        1
# 10357        1
# 10360        1
# 21350        1
# Name: count, Length: 21350, dtype: int64

# %%
df[df["order_id"]==18845]
# Out:
#        order_details_id  order_id        pizza_id  quantity  order_date  \
# 42846             42847     18845       bbq_ckn_m         3  18-11-2015
# 42847             42848     18845      big_meat_s         2  18-11-2015
# 42848             42849     18845     calabrese_m         1  18-11-2015
# 42849             42850     18845   ckn_alfredo_m         1  18-11-2015
# 42850             42851     18845     ckn_pesto_s         1  18-11-2015
# 42851             42852     18845   classic_dlx_m         1  18-11-2015
# 42852             42853     18845   classic_dlx_s         1  18-11-2015
# 42853             42854     18845   four_cheese_l         1  18-11-2015
# 42854             42855     18845  green_garden_m         1  18-11-2015
# 42855             42856     18845      hawaiian_l         1  18-11-2015
# 42856             42857     18845      hawaiian_s         2  18-11-2015
# 42857             42858     18845   ital_cpcllo_m         1  18-11-2015
# ...

# %%
df[["pizza_id","pizza_name"]]
# Out:
#             pizza_id                  pizza_name
# 0         hawaiian_m          The Hawaiian Pizza
# 1      classic_dlx_m    The Classic Deluxe Pizza
# 2      five_cheese_l       The Five Cheese Pizza
# 3        ital_supr_l   The Italian Supreme Pizza
# 4         mexicana_m          The Mexicana Pizza
# ...              ...                         ...
# 48615  ckn_alfredo_m   The Chicken Alfredo Pizza
# 48616  four_cheese_l       The Four Cheese Pizza
# 48617   napolitana_s        The Napolitana Pizza
# 48618     mexicana_l          The Mexicana Pizza
# 48619      bbq_ckn_s  The Barbecue Chicken Pizza
#
# [48620 rows x 2 columns]

# %%
df["quantity"].value_counts()
# there are some pizzas which is buyed in 2 or more quantity at order time.
# Out:
# quantity
# 1    47693
# 2      903
# 3       21
# 4        3
# Name: count, dtype: int64

# %%
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1  01-01-2015
# 1                     2         2  classic_dlx_m         1  01-01-2015
# 2                     3         2  five_cheese_l         1  01-01-2015
# 3                     4         2    ital_supr_l         1  01-01-2015
# 4                     5         2     mexicana_m         1  01-01-2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  31-12-2015
# 48616             48617     21348  four_cheese_l         1  31-12-2015
# 48617             48618     21348   napolitana_s         1  31-12-2015
# 48618             48619     21349     mexicana_l         1  31-12-2015
# 48619             48620     21350      bbq_ckn_s         1  31-12-2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.groupby("order_date")[["total_price"]].sum()
# Out:
#             total_price
# order_date
# 01-01-2015      2713.85
# 01-02-2015      3189.20
# 01-03-2015      1598.55
# 01-04-2015      2176.85
# 01-05-2015      2571.95
# ...                 ...
# 31-05-2015      1717.65
# 31-07-2015      2095.40
# 31-08-2015      2081.35
# 31-10-2015      2744.85
# 31-12-2015      2916.00
#
# [358 rows x 1 columns]

# %%
df.where(df["order_date"]=="01-01-2015")[["total_price"]].sum()
# Total sale in 1st january is $2713.85.
# Out:
# total_price    2713.85
# dtype: float64

# %%
df.groupby("pizza_size")[["total_price"]].sum()
# It seems like customer buys pizza mostly in a large size in comparing of other pizzas.
# Out:
#             total_price
# pizza_size
# L             375318.70
# M             249382.25
# S             178076.50
# XL             14076.00
# XXL             1006.60

# %%
df.groupby("pizza_category")[["total_price"]].sum()
# People love classic pizzas in comparing  of others.
# 23.95% of sales is done by Chicken category.
# 26.90% of sales is done by Classic category.
# 25.45% of sales is done by Supreme category.
# 23.68% of sales is done by Veggie category.
# Out:
#                 total_price
# pizza_category
# Chicken           195919.50
# Classic           220053.10
# Supreme           208197.00
# Veggie            193690.45

# %%
df["pizza_ingredients"].str.contains("Cheese",case=False).value_counts()
# It seems that above 50% of customers eats pizza which includes cheese.
# Out:
# pizza_ingredients
# True     24506
# False    24114
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
193690.45/df["total_price"].sum()
# Out:
# 0.23682590927384214

# %%
plt.bar(df["pizza_category"],df["total_price"])
plt.show()

# %%
fdv=df["pizza_category"].value_counts()
plt.pie(x=fdv.values,labels=fdv.index,autopct="%f",wedgeprops={"edgecolor":"k"},startangle=90)
plt.show()

# %%
plt.barh(df["pizza_name"],df["total_price"])
plt.show()

# %%
import seaborn as sbn

# %%
sbn.scatterplot(x=df["total_price"],y=df["pizza_name"])
plt.show()

# %%
plt.hist(df["pizza_size"],edgecolor="k")
plt.show()

# %%
sbn.scatterplot(x=df["pizza_size"],y=df["pizza_name"],hue=df["pizza_size"])
plt.show()

# %%
df.to_csv("Pizza_sales_project.csv")
